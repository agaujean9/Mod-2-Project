# %%
import pandas as pd
data = pd.read_csv('nba_draft_combine_all_years.csv')

# %%
data[450:520]
# Out:
#      Unnamed: 0                   Player  Year  Draft pick  Height (No Shoes)  \
# 450         450              Nigel Hayes  2016         NaN              78.25
# 451         451              Perry Ellis  2016         NaN              79.00
# 452         452            Robert Carter  2016         NaN              78.75
# 453         453                Ron Baker  2016         NaN              75.25
# 454         454        Sheldon McClellan  2016         NaN              77.00
# 455         455            Troy Williams  2016         NaN              77.75
# 456         456             Wayne Selden  2016         NaN              76.25
# 457         457             Zach Collins  2017        10.0              82.25
# 458         458             Luke Kennard  2017        12.0              76.50
# 459         459         Donovan Mitchell  2017        13.0              73.25
# 460         460              Bam Adebayo  2017        14.0              80.75
# ...
